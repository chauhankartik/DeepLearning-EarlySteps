# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, Input, Flatten, Reshape
from tensorflow.keras.layers import Dense, Conv2DTranspose, BatchNormalization, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
import os
import math

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, .587, 0.114])

# %%
(X_train, _), (X_test, _) = cifar10.load_data()

img_rows = X_train.shape[1]
img_cols = X_train.shape[2]
channels = X_train.shape[3]

imgs_dir = "saved_images"
save_dir = os.path.join(os.getcwd(), imgs_dir)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
input_shape = (img_rows, img_cols, 1)
batch_size = 32
kernel_size = 3
latent_dim = 256
layer_filters = [64, 128, 256]

# %%
imgs = X_test[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test color images (Ground Truth)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/test_color.png' % imgs_dir)
plt.show()


X_train_gray = rgb2gray(X_train)
X_test_gray = rgb2gray(X_test)


imgs = X_test_gray[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Test gray images (Input)')
plt.imshow(imgs, interpolation='none', cmap='gray')
plt.savefig('%s/test_gray.png' % imgs_dir)
plt.show()

# %%
# normalize output train and test color images
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# normalize input train and test grayscale images
X_train_gray = X_train_gray.astype('float32') / 255
X_test_gray = X_test_gray.astype('float32') / 255


X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols,channels)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, channels)

X_train_gray = X_train_gray.reshape(X_train_gray.shape[0], img_rows,img_cols, 1)
X_test_gray = X_test_gray.reshape(X_test_gray.shape[0], img_rows, img_cols, 1)

# %%
inputs = Input(shape=input_shape, name='encoder_input')
x = inputs
# Stack of Conv2D(32)-Conv2D(64)

for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               activation='relu',
               strides=2,
               padding='same')(x)
    
shape = K.int_shape(x)
    
# Latent Vector
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)
encoder = Model(inputs,
                latent,
                name='encoder')

encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               1048832
# =================================================================
# Total params: 1,418,496
# Trainable params: 1,418,496
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense((shape[1]*shape[2]*shape[3]))(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        activation='relu',
                        strides=2,
                        padding='same')(x)

# reconstruct the input
outputs = Conv2DTranspose(filters=channels,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# instantiate decoder model
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 256)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# reshape (Reshape)            (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 16, 16, 128)       295040
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 64)        73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 32, 32, 3)         1731
# =================================================================
# Total params: 2,013,315
# Trainable params: 2,013,315
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder = Model(inputs,
                    decoder(encoder(inputs)),
                    name='autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 32, 32, 1)]       0
# _________________________________________________________________
# encoder (Model)              (None, 256)               1418496
# _________________________________________________________________
# decoder (Model)              (None, 32, 32, 3)         2013315
# =================================================================
# Total params: 3,431,811
# Trainable params: 3,431,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
save_model_dir = os.path.join(os.getcwd(), "saved_models")
model_name = 'colourizarion_autoencoder.{epoch:03d}.h5'
if not os.path.isdir(save_model_dir):
    os.makedirs(save_model_dir)
filepath = os.path.join(save_model_dir, model_name)

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)

autoencoder.compile(loss='mse', optimizer='adam')

callbacks = [lr_reducer, checkpoint]
autoencoder.fit(X_train_gray,
                X_train,
                validation_data=(X_test_gray, X_test),
                epochs=50,
                batch_size=batch_size,
                callbacks=callbacks)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 00001: val_loss improved from inf to 0.01118, saving model to /content/saved_models/colourizarion_autoencoder.001.h5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0159 - val_loss: 0.0112 - lr: 0.0010
# Epoch 2/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0102
# Epoch 00002: val_loss improved from 0.01118 to 0.00956, saving model to /content/saved_models/colourizarion_autoencoder.002.h5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0102 - val_loss: 0.0096 - lr: 0.0010
# Epoch 3/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 00003: val_loss improved from 0.00956 to 0.00895, saving model to /content/saved_models/colourizarion_autoencoder.003.h5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0092 - val_loss: 0.0090 - lr: 0.0010
# Epoch 4/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 00004: val_loss improved from 0.00895 to 0.00840, saving model to /content/saved_models/colourizarion_autoencoder.004.h5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0086 - val_loss: 0.0084 - lr: 0.0010
# Epoch 5/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 00005: val_loss improved from 0.00840 to 0.00809, saving model to /content/saved_models/colourizarion_autoencoder.005.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0082 - val_loss: 0.0081 - lr: 0.0010
# Epoch 6/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 00006: val_loss improved from 0.00809 to 0.00805, saving model to /content/saved_models/colourizarion_autoencoder.006.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0079 - val_loss: 0.0080 - lr: 0.0010
# Epoch 7/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0076
# Epoch 00007: val_loss improved from 0.00805 to 0.00779, saving model to /content/saved_models/colourizarion_autoencoder.007.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0076 - val_loss: 0.0078 - lr: 0.0010
# Epoch 8/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0074
# Epoch 00008: val_loss did not improve from 0.00779
# 1563/1563 [==============================] - 35s 22ms/step - loss: 0.0074 - val_loss: 0.0081 - lr: 0.0010
# Epoch 9/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 00009: val_loss improved from 0.00779 to 0.00766, saving model to /content/saved_models/colourizarion_autoencoder.009.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0071 - val_loss: 0.0077 - lr: 0.0010
# Epoch 10/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0069
# Epoch 00010: val_loss did not improve from 0.00766
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0069 - val_loss: 0.0078 - lr: 0.0010
# Epoch 11/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0067
# Epoch 00011: val_loss improved from 0.00766 to 0.00765, saving model to /content/saved_models/colourizarion_autoencoder.011.h5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.0067 - val_loss: 0.0076 - lr: 0.0010
# Epoch 12/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 00012: val_loss did not improve from 0.00765
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0064 - val_loss: 0.0081 - lr: 0.0010
# Epoch 13/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 00013: val_loss improved from 0.00765 to 0.00760, saving model to /content/saved_models/colourizarion_autoencoder.013.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0062 - val_loss: 0.0076 - lr: 0.0010
# Epoch 14/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00014: val_loss did not improve from 0.00760
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0059 - val_loss: 0.0078 - lr: 0.0010
# Epoch 15/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0051
# Epoch 00015: val_loss improved from 0.00760 to 0.00752, saving model to /content/saved_models/colourizarion_autoencoder.015.h5
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0051 - val_loss: 0.0075 - lr: 3.1623e-04
# Epoch 16/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0048
# Epoch 00016: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0048 - val_loss: 0.0076 - lr: 3.1623e-04
# Epoch 17/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0047
# Epoch 00017: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0047 - val_loss: 0.0076 - lr: 3.1623e-04
# Epoch 18/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 00018: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0046 - val_loss: 0.0076 - lr: 3.1623e-04
# Epoch 19/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0044
# Epoch 00019: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0044 - val_loss: 0.0076 - lr: 3.1623e-04
# Epoch 20/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00020: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0043 - val_loss: 0.0078 - lr: 3.1623e-04
# Epoch 21/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0041
# Epoch 00021: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0041 - val_loss: 0.0077 - lr: 1.0000e-04
# Epoch 22/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 00022: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0040 - val_loss: 0.0077 - lr: 1.0000e-04
# Epoch 23/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 00023: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0039 - val_loss: 0.0078 - lr: 1.0000e-04
# Epoch 24/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0039
# Epoch 00024: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0039 - val_loss: 0.0078 - lr: 1.0000e-04
# Epoch 25/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 00025: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0039 - val_loss: 0.0078 - lr: 1.0000e-04
# Epoch 26/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0038
# Epoch 00026: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0038 - val_loss: 0.0078 - lr: 3.1623e-05
# Epoch 27/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 00027: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0038 - val_loss: 0.0079 - lr: 3.1623e-05
# Epoch 28/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00028: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0078 - lr: 3.1623e-05
# Epoch 29/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00029: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0078 - lr: 3.1623e-05
# Epoch 30/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
#
# Epoch 00030: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-05
# Epoch 31/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00031: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 1.0000e-05
# Epoch 32/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00032: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 1.0000e-05
# Epoch 33/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00033: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 1.0000e-05
# Epoch 34/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00034: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 1.0000e-05
# Epoch 35/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
#
# Epoch 00035: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 1.0000e-05
# Epoch 36/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00036: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-06
# Epoch 37/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00037: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-06
# Epoch 38/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00038: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-06
# Epoch 39/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00039: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-06
# Epoch 40/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.0000000553323957e-06.
#
# Epoch 00040: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0037 - val_loss: 0.0079 - lr: 3.1623e-06
# Epoch 41/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00041: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 1.0000e-06
# Epoch 42/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00042: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 1.0000e-06
# Epoch 43/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00043: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 1.0000e-06
# Epoch 44/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00044: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 1.0000e-06
# Epoch 45/50
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 5e-07.
#
# Epoch 00045: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 1.0000e-06
# Epoch 46/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00046: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 5.0000e-07
# Epoch 47/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00047: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 5.0000e-07
# Epoch 48/50
# 1563/1563 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 00048: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 5.0000e-07
# Epoch 49/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00049: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 5.0000e-07
# Epoch 50/50
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.0036
# Epoch 00050: val_loss did not improve from 0.00752
# 1563/1563 [==============================] - 35s 23ms/step - loss: 0.0036 - val_loss: 0.0079 - lr: 5.0000e-07

# %%
x_decoded = autoencoder.predict(X_test_gray)
# display the 1st 100 colorized images
imgs = x_decoded[:100]
imgs = imgs.reshape((10, 10, img_rows, img_cols, channels))
imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure()
plt.axis('off')
plt.title('Colorized test images (Predicted)')
plt.imshow(imgs, interpolation='none')
plt.savefig('%s/colorized.png' % imgs_dir)
plt.show()
